# %% [markdown]
# # Codes for running large scale Wind Data Downloads

# %% [markdown]
# The script uses shapely points querried from pywkt site lookup written to csv in spatial intersect.

# %%
# Select state, year, and attributes for which to download data
state = "Iowa"
interval = 5 # set wind resolution to 5 min (default is sample every 60 mins)
years = [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014] # available years
attributes = ['windspeed_10m', 'windspeed_100m', 'temperature_10m', 'temperature_100m', 'winddirection_100m']

# %%
# Package Imports
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
from io import StringIO
import sys
import time
import csv
import logging
import os
from os import path
from shapely import wkb, wkt
from shapely.geometry import Point, shape, Polygon
import traceback
import pywtk
from pywtk.site_lookup import get_3tiersites_from_wkt
import fiona

# Imports for timing download
from tqdm import tqdm
from tqdm.notebook import trange

# %%
# read csvs
wkt_locations = pd.read_csv("US_wind_locations_3.csv")
corn = pd.read_csv("~/Documents/Schoolwork/Junior Fall/EPS 168/project/data/data_yield/Maize_1999_2019_NASS.csv")

# %%
# Clean Data
corn.rename(columns={'State ANSI': 'STATEFP', 'County ANSI':'COUNTYFP'}, inplace=True) # match columns
corn_clean = corn.dropna(subset=['STATEFP','COUNTYFP']).copy()

# Add modified FIPS column to yield and wkt data 
corn_clean['ST_CT'] = [(str(elt[0])+"_"+str(int(elt[1]))) for elt in \
                       zip(np.array(corn_clean['STATEFP'].values), np.array(corn_clean['COUNTYFP'].values))]
wkt_locations['ST_CT'] = [(str(elt[0])+"_"+str(elt[1])) for elt in \
                       zip(np.array(wkt_locations['STATEFP'].values), np.array(wkt_locations['COUNTYFP'].values))]

# extract wkt locations which contain a FIPS matching one in the corn dataset
to_download = wkt_locations.loc[wkt_locations['ST_CT'].isin(set(corn_clean['ST_CT'].values))]
to_download.head()
# Out:
#    Unnamed: 0       NAME     STATE  STATEFP  COUNTYFP          NAMELSAD  \
# 0           0     Cuming  Nebraska       31        39     Cuming County
# 5           5  Lancaster  Nebraska       31       109  Lancaster County
# 6           6  Lancaster  Nebraska       31       109  Lancaster County
# 7           7  Lancaster  Nebraska       31       109  Lancaster County
# 8           8   Nuckolls  Nebraska       31       129   Nuckolls County
#
#                           POINT   SITE   ST_CT
# 0  POINT (-96.985748 41.851967)  66913   31_39
# 5    POINT (-96.723145 40.7766)  54135  31_109
# 6  POINT (-96.575378 40.703255)  53444  31_109
# 7     POINT (-96.7229 40.75803)  53954  31_109
# 8  POINT (-98.216003 40.032036)  48472  31_129

# %%
# Select sites from dataframe which match state for download
selected_download = to_download.loc[to_download['STATE']== state]
print("The following will implement the download of {} wind data sites.".format(len(selected_download)))
selected_download.head()
# Out:
# The following will implement the download of 267 wind data sites.
#      Unnamed: 0     NAME STATE  STATEFP  COUNTYFP        NAMELSAD  \
# 266         266  Decatur  Iowa       19        53  Decatur County
# 267         267  Decatur  Iowa       19        53  Decatur County
# 368         368    Cedar  Iowa       19        31    Cedar County
# 369         369    Cedar  Iowa       19        31    Cedar County
# 370         370    Cedar  Iowa       19        31    Cedar County
#
#                                     POINT   SITE  ST_CT
# 266    POINT (-93.77731300000001 40.8857)  55562  19_53
# 267          POINT (-93.557129 40.862282)  55352  19_53
# 368          POINT (-90.993286 41.851456)  68641  19_31
# 369           POINT (-91.016632 41.87117)  68898  19_31
# 370  POINT (-90.96993999999999 41.831738)  68365  19_31

# %%
# Functions for downloading data
def point_download(point, interval, years):
    url = 'https://developer.nrel.gov/api/wind-toolkit/v2/wind/wtk-download.csv?'
    df = 'tmp'
    for yr in range(0,len(years)):
        time.sleep(2)
        year = years[yr]
        params = { 'api_key' : '037P8C9W1gMsO4cNFDFvUYvTDnIhMlA3NSVhXdCC', 'wkt' : point,
                   'names' : [year], 'email' : 'julians3.1415@gmail.com', 'interval': interval}
        response = requests.get(url, params)
        raw_data = StringIO(response.text)
        df_yr = pd.read_csv(raw_data, sep = ",", header=1)
        if type(df)==str:
            df = df_yr
        else:
            df = pd.concat([df, df_yr], axis=0)
    return df

# %%
# %%time
# Iterate through dataframe for download (ok to do so because time is within loop)
for index in tqdm(range(73:len(selected_download))):
    row = selected_download.iloc[index]
    state, county, site = row['STATE'], row['NAME'], row['SITE'] # parameters for naming
    point = row['POINT'] # extract point for download
    df = point_download(point, interval, years)
    df.to_csv("~/Downloads/Direcho/{}/{}_{}_{}_{}.csv".format(state, site, state, county, interval)) # save to csv

# %%
# rename corn data columns to be able to merge with site data. 

# merge dataframes to get rows containing crop and wind station data
# merged_df = wkt_locations.merge(corn, how = 'inner', on = ['STATEFP', 'COUNTYFP'])
# corn.columns
# Out:
# Index([u'Program', u'Year', u'Period', u'Week Ending', u'Geo Level', u'State',
#        u'STATEFP', u'Ag District', u'Ag District Code', u'County', u'COUNTYFP',
#        u'Zip Code', u'Region', u'watershed_code', u'Watershed', u'Commodity',
#        u'Data Item', u'Domain', u'Domain Category', u'Value', u'CV (%)'],
#       dtype='object')

# %%
#corn_unique = corn[['STATEFP','COUNTYFP']].drop_duplicates(subset=['STATEFP','COUNTYFP']).dropna().astype(int)

# %%
# ar = pd.DataFrame(np.array([1,1]))
# ar.isin(corn_unique)
# print(ar)
# Out:
#    0
# 0  1
# 1  1

# %%
# wkt_test = wkt_locations[["STATEFP","COUNTYFP"]]
# count = 0
# for i in range(len(wkt_test)):
#     if (wkt_test.iloc[i,:].isin(corn_unique).all().any()):
#     #if wkt_test.iloc[i,:].isin(corn_unique[['STATEFP','COUNTYFP']]).all():
#         count += 1
# print(count)
# Out:
# 0

# %%
# test = np.vstack((np.array(corn['STATEFP'].values), np.array(corn['COUNTYFP'].values)))
# strings = [f'{int(elt[])}']
# Out:
#   File "<fstring>", line 1
#     (int(elt[]))
#              ^
# SyntaxError: invalid syntax

# %%
corn_clean = corn.dropna(subset=['STATEFP','COUNTYFP']).copy()
corn_clean['ST_CT'] = [(str(elt[0])+"_"+str(int(elt[1]))) for elt in zip(np.array(corn_clean['STATEFP'].values), np.array(corn_clean['COUNTYFP'].values))]# if np.isnan(elt[1]) == False] 
wkt_locations['ST_CT'] = [(str(elt[0])+"_"+str(elt[1])) for elt in zip(np.array(wkt_locations['STATEFP'].values), np.array(wkt_locations['COUNTYFP'].values))]
corn_clean.head()
# Out:
#   Program  Year Period  Week Ending Geo Level    State  STATEFP  \
# 0  SURVEY  2019   YEAR          NaN    COUNTY  ALABAMA        1
# 1  SURVEY  2019   YEAR          NaN    COUNTY  ALABAMA        1
# 2  SURVEY  2019   YEAR          NaN    COUNTY  ALABAMA        1
# 4  SURVEY  2019   YEAR          NaN    COUNTY  ALABAMA        1
# 5  SURVEY  2019   YEAR          NaN    COUNTY  ALABAMA        1
#
#                    Ag District  Ag District Code   County  ...  Region  \
# 0                   BLACK BELT                40  AUTAUGA  ...     NaN
# 1                   BLACK BELT                40   DALLAS  ...     NaN
# 2                   BLACK BELT                40   ELMORE  ...     NaN
# 4                   BLACK BELT                40    PERRY  ...     NaN
# 5  COASTAL PLAINS & GULF COAST                50  BALDWIN  ...     NaN
#
#    watershed_code  Watershed  Commodity  \
# 0               0        NaN       CORN
# 1               0        NaN       CORN
# 2               0        NaN       CORN
# 4               0        NaN       CORN
# 5               0        NaN       CORN
#
#                                     Data Item Domain Domain Category  Value  \
# 0  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  TOTAL   NOT SPECIFIED  165.6
# 1  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  TOTAL   NOT SPECIFIED  133.3
# 2  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  TOTAL   NOT SPECIFIED  104.3
# 4  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  TOTAL   NOT SPECIFIED  110.2
# 5  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  TOTAL   NOT SPECIFIED  150.9
#
#   CV (%)  ST_CT
# 0    NaN    1_1
# 1    NaN   1_47
# 2    NaN   1_51
# 4    NaN  1_105
# 5    NaN    1_3
#
# [5 rows x 22 columns]

# %%
to_download = wkt_locations.loc[wkt_locations['ST_CT'].isin(set(corn_clean['ST_CT'].values))]

# %%
to_download
# Out:
#       Unnamed: 0          NAME         STATE  STATEFP  COUNTYFP  \
# 0              0        Cuming      Nebraska       31        39
# 5              5     Lancaster      Nebraska       31       109
# 6              6     Lancaster      Nebraska       31       109
# 7              7     Lancaster      Nebraska       31       109
# 8              8      Nuckolls      Nebraska       31       129
# 9              9      Nuckolls      Nebraska       31       129
# 10            10      Nuckolls      Nebraska       31       129
# 11            11     Minnehaha  South Dakota       46        99
# 12            12     Minnehaha  South Dakota       46        99
# 13            13     Minnehaha  South Dakota       46        99
# 18            18       Clinton      Kentucky       21        53
# 19            19       Hancock          Ohio       39        63
# 20            20       Hancock          Ohio       39        63
# 21            21       Hancock          Ohio       39        63
# 22            22          Hale         Texas       48       189
# 23            23          Hale         Texas       48       189
# 24            24          Hale         Texas       48       189
# 26            26     Armstrong         Texas       48        11
# 27            27     Armstrong         Texas       48        11
# 28            28     Armstrong         Texas       48        11
# 29            29         Allen          Ohio       39         3
# 30            30         Allen          Ohio       39         3
# 31            31         Allen          Ohio       39         3
# 32            32      McDuffie       Georgia       13       189
# 33            33          Sauk     Wisconsin       55       111
# 34            34          Sauk     Wisconsin       55       111
# 35            35          Sauk     Wisconsin       55       111
# 42            42        Beaver  Pennsylvania       42         7
# 44            44         Henry      Missouri       29        83
# 45            45         Henry      Missouri       29        83
# ...          ...           ...           ...      ...       ...
# 6376        6376  Westmoreland  Pennsylvania       42       129
# 6380        6380          Cass          Iowa       19        29
# 6381        6381          Cass          Iowa       19        29
# 6382        6382          Cass          Iowa       19        29
# 6383        6383        Mercer          Ohio       39       107
# 6384        6384        Mercer          Ohio       39       107
# 6385        6385        Mercer          Ohio       39       107
# 6396        6396       Jackson        Kansas       20        85
# 6397        6397       Jackson        Kansas       20        85
# 6398        6398       Jackson        Kansas       20        85
# 6399        6399      Franklin     Louisiana       22        41
# 6400        6400       Webster   Mississippi       28       155
# 6404        6404        Cherry      Nebraska       31        31
# 6405        6405        Cherry      Nebraska       31        31
# 6406        6406        Cherry      Nebraska       31        31
# 6410        6410    New Madrid      Missouri       29       143
# 6411        6411    New Madrid      Missouri       29       143
# 6412        6412    New Madrid      Missouri       29       143
# 6415        6415   Mecklenburg      Virginia       51       117
# 6416        6416       Webster      Kentucky       21       233
# 6417        6417      Garfield      Oklahoma       40        47
# 6418        6418      Garfield      Oklahoma       40        47
# 6419        6419      Garfield      Oklahoma       40        47
# 6423        6423       Lenawee      Michigan       26        91
# 6424        6424       Lenawee      Michigan       26        91
# 6425        6425       Lenawee      Michigan       26        91
# 6426        6426        Roseau     Minnesota       27       135
# 6427        6427        Roseau     Minnesota       27       135
# 6428        6428        Roseau     Minnesota       27       135
# 6429        6429       Madison   Mississippi       28        89
#
#                  NAMELSAD                                 POINT    SITE  \
# 0           Cuming County          POINT (-96.985748 41.851967)   66913
# 5        Lancaster County            POINT (-96.723145 40.7766)   54135
# 6        Lancaster County          POINT (-96.575378 40.703255)   53444
# 7        Lancaster County             POINT (-96.7229 40.75803)   53954
# 8         Nuckolls County          POINT (-98.216003 40.032036)   48472
# 9         Nuckolls County  POINT (-98.26370199999999 40.012466)   48360
# 10        Nuckolls County          POINT (-98.215332 40.013504)   48362
# 11       Minnehaha County          POINT (-96.475342 43.567009)   87915
# 12       Minnehaha County          POINT (-97.096497 43.804649)   91048
# 13       Minnehaha County          POINT (-97.121582 43.767155)   90675
# 18         Clinton County           POINT (-85.043762 36.71804)   32677
# 19         Hancock County          POINT (-83.693665 40.844772)   63407
# 20         Hancock County          POINT (-83.867554 41.090389)   65989
# 21         Hancock County   POINT (-83.62091100000001 40.83622)   63410
# 22            Hale County         POINT (-101.836823 34.295345)   14656
# 23            Hale County          POINT (-101.64151 34.087051)   14070
# 24            Hale County          POINT (-101.789459 34.26152)   14580
# 26       Armstrong County         POINT (-101.333374 34.929729)   17372
# 27       Armstrong County         POINT (-101.529358 34.863728)   17023
# 28       Armstrong County         POINT (-101.449402 34.978405)   17781
# 29           Allen County  POINT (-83.90252700000001 40.793919)   62482
# 30           Allen County          POINT (-83.992188 40.841759)   62980
# 31           Allen County          POINT (-84.190918 40.714146)   61069
# 32        McDuffie County          POINT (-82.329285 33.350677)   14292
# 33            Sauk County          POINT (-89.803375 43.431221)   88564
# 34            Sauk County          POINT (-89.620422 43.458111)   89099
# 35            Sauk County           POINT (-89.64801 43.441032)   88839
# 42          Beaver County          POINT (-80.500305 40.570904)   64971
# 44           Henry County          POINT (-93.909119 38.497272)   40366
# 45           Henry County          POINT (-93.932129 38.516228)   40451
# ...                   ...                                   ...     ...
# 6376  Westmoreland County  POINT (-79.18609600000001 40.366375)   64974
# 6380          Cass County          POINT (-94.950836 41.200966)   59000
# 6381          Cass County  POINT (-94.75299099999999 41.217403)   59230
# 6382          Cass County          POINT (-94.797546 41.459446)   62124
# 6383        Mercer County  POINT (-84.48593099999999 40.465668)   57842
# 6384        Mercer County          POINT (-84.710083 40.452633)   57447
# 6385        Mercer County          POINT (-84.468414 40.557484)   58856
# 6396       Jackson County          POINT (-95.796875 39.221523)   43780
# 6397       Jackson County           POINT (-95.749054 39.22142)   43782
# 6398       Jackson County          POINT (-95.772949 39.221478)   43781
# 6399      Franklin Parish  POINT (-91.66229199999999 32.075367)    9700
# 6400       Webster County  POINT (-89.13763400000001 33.696381)   13167
# 6404        Cherry County         POINT (-102.015503 42.676109)   78844
# 6405        Cherry County         POINT (-101.124176 42.926846)   80884
# 6406        Cherry County          POINT (-100.309387 42.92474)   80504
# 6410    New Madrid County          POINT (-89.537048 36.389999)   26939
# 6411    New Madrid County          POINT (-89.535217 36.408333)   27081
# 6412    New Madrid County           POINT (-89.554321 36.44648)   27358
# 6415   Mecklenburg County          POINT (-78.471558 36.763096)   39524
# 6416       Webster County          POINT (-87.661163 37.583431)   37454
# 6417      Garfield County          POINT (-97.752686 36.547688)   26587
# 6418      Garfield County  POINT (-98.04980500000001 36.523605)   26421
# 6419      Garfield County          POINT (-97.730255 36.566479)   26762
# 6423       Lenawee County  POINT (-83.93139600000001 41.887047)   75665
# 6424       Lenawee County          POINT (-83.815552 41.836269)   75262
# 6425       Lenawee County          POINT (-83.923889 41.923801)   76034
# 6426        Roseau County   POINT (-95.70462000000001 48.59581)  122339
# 6427        Roseau County  POINT (-95.78851299999999 48.726212)  122890
# 6428        Roseau County            POINT (-95.844849 48.7449)  122937
# 6429       Madison County          POINT (-90.192719 32.451344)   10690
#
#        ST_CT
# 0      31_39
# 5     31_109
# 6     31_109
# 7     31_109
# 8     31_129
# 9     31_129
# 10    31_129
# 11     46_99
# 12     46_99
# 13     46_99
# 18     21_53
# 19     39_63
# 20     39_63
# 21     39_63
# 22    48_189
# 23    48_189
# 24    48_189
# 26     48_11
# 27     48_11
# 28     48_11
# 29      39_3
# 30      39_3
# 31      39_3
# 32    13_189
# 33    55_111
# 34    55_111
# 35    55_111
# 42      42_7
# 44     29_83
# 45     29_83
# ...      ...
# 6376  42_129
# 6380   19_29
# 6381   19_29
# 6382   19_29
# 6383  39_107
# 6384  39_107
# 6385  39_107
# 6396   20_85
# 6397   20_85
# 6398   20_85
# 6399   22_41
# 6400  28_155
# 6404   31_31
# 6405   31_31
# 6406   31_31
# 6410  29_143
# 6411  29_143
# 6412  29_143
# 6415  51_117
# 6416  21_233
# 6417   40_47
# 6418   40_47
# 6419   40_47
# 6423   26_91
# 6424   26_91
# 6425   26_91
# 6426  27_135
# 6427  27_135
# 6428  27_135
# 6429   28_89
#
# [4894 rows x 9 columns]

# %% [markdown]
# ## Meeting 11/6
# How do we optimiize a damage function so that we get the yield outcome as close as possible. MLR - convert every windspeed into a unit of damage. Look at log yield (fraction of yield). Different yields in different places - accounts for this. As windspeed decreases above 15m a second, take the excess and multiply by $\beta$ coefficient. Increase 1%/(m/s) per event. Transform windspeed into damages and then sum damages. This is now an accumulated damage. One outcome and one yield. Adjust the rate at which the damage is occuring.

# %%
# Select data for Kansas Download
kansas_download = to_download.loc[to_download['STATE']=="Kansas"]
print(f"The following will implement the download of {len(kansas_download)} wind data sites")
kansas_download.head()
# Out:
# The following will implement the download of 268 wind data sites
#      Unnamed: 0       NAME   STATE  STATEFP  COUNTYFP          NAMELSAD  \
# 121         121  Greenwood  Kansas       20        73  Greenwood County
# 122         122  Greenwood  Kansas       20        73  Greenwood County
# 123         123  Greenwood  Kansas       20        73  Greenwood County
# 135         135   Doniphan  Kansas       20        43   Doniphan County
# 136         136   Doniphan  Kansas       20        43   Doniphan County
#
#                                     POINT   SITE  ST_CT
# 121          POINT (-96.524567 37.667553)  35665  20_73
# 122  POINT (-96.50140399999999 37.686131)  35828  20_73
# 123          POINT (-96.431702 37.723366)  36122  20_73
# 135  POINT (-95.33523599999999 39.923622)  47564  20_43
# 136          POINT (-95.334656 39.979237)  47994  20_43

# %%
# Functions for downloading data
def point_download(point, interval, years):
    url = 'https://developer.nrel.gov/api/wind-toolkit/v2/wind/wtk-download.csv?'
    df = 'tmp'
    for yr in range(0,len(years)):
        time.sleep(2)
        year = years[yr]
        params = { 'api_key' : '037P8C9W1gMsO4cNFDFvUYvTDnIhMlA3NSVhXdCC', 'wkt' : point,
                   'names' : [year], 'email' : 'julians3.1415@gmail.com', 'interval': interval}
        response = requests.get(url, params)
        #print(response.content)
        raw_data = StringIO(response.text)
        df_yr = pd.read_csv(raw_data, sep = ",", header=1)#[columns]
        if type(df)==str:
            df = df_yr
        else:
            df = pd.concat([df, df_yr], axis=0)
    return df
# static
years = [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014] # available years
attributes = ['windspeed_10m', 'windspeed_100m', 'temperature_10m', 'temperature_100m', 'winddirection_100m']

# %%
# %%time
interval = 5 # set wind resolution to 5 min (default is sample every 60 mins)
from tqdm import tqdm
from tqdm.notebook import trange # Get timing 
# Iterate through dataframe for download (ok to do so because time is within loop)
for index in tqdm(range(7+102,len(kansas_download))):
    row = kansas_download.iloc[index]
    state, county, site = row['STATE'], row['NAME'], row['SITE'] # parameters for naming
    point = row['POINT'] # extract point for download
    df = point_download(point, interval, years)
    df.to_csv(f'../../direcho_data/{site}_{state}_{county}_{interval}.csv')
# Out:
# 100%|██████████| 159/159 [9:43:04<00:00, 220.03s/it]
# CPU times: user 1h 6min 46s, sys: 5min 17s, total: 1h 12min 4s
# Wall time: 9h 43min 4s

# %%
# %%time
for index in tqdm(range(6, len(kansas_download))):
    print(kansas_download.iloc[index])

# %%
kansas_d
