# %% [markdown]
# ## Wind Speed Function
# we have the following function for determining growing and killing degree days (respectively):
# $$
# g(h) = \begin{cases}
# 0, &h\leq 10\\
# h-10, &10\leq h\leq 28\\
# 18, &28 \leq h\\
# \end{cases}
# \qquad
# g(h) = \begin{cases}
# 0, &h \leq 28 \\
# h-28, &h > 28
# \end{cases}
# $$
# where the computed value for the mean temperature is then multiplied over the length of the growing season. We will base our initial function for killing wind speeds on a similar formulation:
# $$g_k(w) = \begin{cases}
# 0, &w \leq 15 \\
# (w - 15)^3, &w > 15
# \end{cases}$$
# where $t$ is the estimated duration of the event (rounded to the nearest hours).
# We also might want to compute a "growing wind" variable:
# $$g_g(w) = \begin{cases}
# 0, &w \leq 2 \\
# w - 2, &2 \leq w \leq 7 \\
# 12-w, &w > 7 \\
# 0, &w > 12
# \end{cases}$$

# %%
### Import basic libraries
import numpy as np
import pandas as pd
import sklearn as sk
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
# %matplotlib inline
import time
import glob

# Figure factory 
import plotly 
import plotly.figure_factory as ff
import geopandas

# %%
def ws_func(w):
    if w <= 15:
        return 0
    else:
        return w-15
ws_func_v = np.vectorize(ws_func)

def gws_func(w):
    if w <= 2:
        return 0
    elif w <= 7:
        return w - 2
    elif w <= 12:
        return 12 - w
    else:
        return 0
gws_func_v = np.vectorize(gws_func)

# %%
# Let's read in a lot of wind data!
county_yield = pd.read_csv("../../data/data_yield/USA_county_yield_gsw.csv")
kansas = county_yield.loc[county_yield['State'] == 'KANSAS']
filenames = glob.glob('../../direcho_compact/*.csv')

# %%
def compress_data(height = 'wind_10ms', filenames = filenames):
    print(height)
    data_all = []
    for i in range(len(filenames)):
        wind_i = pd.read_csv(filenames[i])
        county_name = filenames[i].split("_")[-2].upper()
        county_data = kansas.loc[kansas['County'] == county_name]
        c_year = county_data["Year"].unique()
        w_year = wind_i["Year"].unique()
        years = np.intersect1d(c_year, w_year)
        county_gs = county_data[county_data["Year"].isin(years)]
        wind_gs = wind_i[wind_i["Year"].isin(years)]
        wind_gs = wind_gs[(wind_gs["Month"] >= 4) & (wind_gs["Month"] <= 10)]
        for y in years:
            wind_gs_y = wind_gs.loc[wind_gs["Year"] == y]
            county_gs_y = county_gs.loc[county_gs["Year"] == y]
            w_gs_y = wind_gs_y[height]
            growing_winds = np.sum(gws_func_v(w_gs_y))
            killing_winds = np.sum(ws_func_v(w_gs_y))
            data = np.append(county_gs_y.iloc[:,[1, 5, 12, 14, 15]].values, [growing_winds, killing_winds]).tolist()
            data_all.append(data)
    return(data_all)
def evaluate(data):
    data_arr = np.array(data)
    ln_yield = data_arr[:,2].astype(np.float64)
    covariates = data_arr[:,3:7].astype(np.float64)
    #Linear Model
    print("Linear Model")
    model = LinearRegression()
    model.fit(covariates, ln_yield)
    y_preds = model.predict(covariates)
    print("\tr-squared:", r2_score(ln_yield, y_preds))
    print("\tCoefficients", model.coef_)
    print("\tIntercept:", model.intercept_)
    #Hmm that's not great...let's try a polynomial transform?
    print("Polynomial Model")
    poly = PolynomialFeatures(3)
    cov_poly = poly.fit_transform(covariates[:,-1].reshape(-1,1))
    #print(cov_poly)
    covariates_poly = np.hstack((covariates[:,0:1], cov_poly))
    model = LinearRegression()
    model.fit(covariates_poly, ln_yield)
    y_preds = model.predict(covariates_poly)
    print("\tr-squared:", r2_score(ln_yield, y_preds))
    print("\tCoefficients", model.coef_)
    print("\tIntercept:", model.intercept_)

# %%
data_all = compress_data()
##wind coefficient is still positive at 40m, 60m, 80m, 100m (error at 120m)
evaluate(data_all)
#county fixed effects and then also county specific linear trend 
#also plot time series of yield and wind (growing season) average)
# Out:
# wind_10ms
# Linear Model
# 	r-squared: 0.6155261979717126
# 	Coefficients [ 6.90482450e-02 -1.29363149e+00  1.31316036e-05  6.49823299e-03]
# 	Intercept: 4.542060097273341
# Polynomial Model
# 	r-squared: 0.4029501636346341
# 	Coefficients [-3.37694463e-01  8.40843508e-15 -3.00621521e-02  1.13871275e-03
#  -8.47795483e-06]
# 	Intercept: 7.926860840181506

# %%
data_all = compress_data(height = 'wind speed at 140m (m/s)') #first?
evaluate(data_all)
# Out:
# wind speed at 140m (m/s)
# C:\Users\18595\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3263: DtypeWarning: Columns (40) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Linear Model
# 	r-squared: 0.5832131645929959
# 	Coefficients [ 1.68641297e-03 -1.04838219e+00 -3.74173616e-05  1.22662431e-04]
# 	Intercept: 5.554528244125134
# Polynomial Model
# 	r-squared: 0.3887776157007108
# 	Coefficients [-3.03293349e-01 -5.70371384e-10  1.57887976e-03 -2.57974945e-06
#   1.20358040e-09]
# 	Intercept: 7.2512203001333075

# %% [markdown]
# The following regressions were performed on compressed 5-minute data.

# %%
filenames2 = glob.glob('C:\\Users\\18595\\wind_project\\data_5\\*.csv')
data_all2 = compress_data(height = 'wind_10ms', filenames = filenames2)
evaluate(data_all2)
# Out:
# wind_10ms
# Linear Model
# 	r-squared: 0.6707827941976912
# 	Coefficients [ 1.59996478e-01 -1.49912324e+00  3.57988287e-05  1.17106665e-02]
# 	Intercept: 3.485315595433608
# Polynomial Model
# 	r-squared: 0.3737385557888414
# 	Coefficients [-3.51901090e-01  1.00991264e-14 -4.61703372e-02  2.74640379e-03
#  -4.59008201e-05]
# 	Intercept: 8.091414985176689

# %%
data_all2 = compress_data(height = 'wind_100ms', filenames = filenames2)
evaluate(data_all2)
# Out:
# wind_100ms
# Linear Model
# 	r-squared: 0.6667576662462608
# 	Coefficients [ 8.96035006e-02 -1.32166354e+00 -3.32440103e-05  2.24851560e-04]
# 	Intercept: 4.812175821513596
# Polynomial Model
# 	r-squared: 0.38037477771080985
# 	Coefficients [-3.13173354e-01 -1.95924871e-09 -2.04031657e-03  3.61998929e-06
#  -1.61091642e-09]
# 	Intercept: 7.831439069041192

# %% [markdown]
# ## Try Number 2 after Jon's Feedback!
# Let's start with some time series:

# %%
#also plot time series of yield and wind (growing season) average) --> done!
#county fixed effects and then also county specific linear trend 
def plot_data(filenames = filenames, height = 'wind_10ms'):
    data_plt = []
    for i in range(len(filenames)):
        wind_i = pd.read_csv(filenames[i])
        county_name = filenames[i].split("_")[-2].upper()
        county_data = kansas.loc[kansas['County'] == county_name]
        c_year = county_data["Year"].unique()
        w_year = wind_i["Year"].unique()
        years = np.intersect1d(c_year, w_year)
        county_gs = county_data[county_data["Year"].isin(years)]
        wind_gs = wind_i[wind_i["Year"].isin(years)]
        wind_gs = wind_gs[(wind_gs["Month"] >= 4) & (wind_gs["Month"] <= 10)]
        for y in years:
            wind_gs_y = wind_gs.loc[wind_gs["Year"] == y]
            county_gs_y = county_gs.loc[county_gs["Year"] == y]
            w_gs_y = wind_gs_y[height]
            average_winds = np.mean(w_gs_y)
            data = np.append(county_gs_y.iloc[:,[1,5,12,14,15]].values, average_winds).tolist() #,12,14,15
            data_plt.append(data)
    return data_plt

# %%
data_plt = np.array(plot_data())
df_plt = pd.DataFrame(data_plt, columns = ['Year', 'County', 'Log-Yield', 'GDD', 'KDD', 'Average Windspeed (m/s)'])
print(df_plt.head())
# Out:
#    Year   County           Log-Yield                GDD                  KDD  \
# 0  2007  JACKSON  4.7791234931115305    9.8280533345053   0.4832467508926889
# 1  2009  JACKSON      4.969813299576  8.183017944897191  0.23118986809024497
# 2  2010  JACKSON    4.48638664999812  9.589805020612769    0.572945128036948
# 3  2011  JACKSON    4.75617305952462   9.54341130947772    0.749284874812784
# 4  2012  JACKSON    4.00733318523247   10.5468887051604   0.9158260897377629
#
#   Average Windspeed (m/s)
# 0       4.147151479750785
# 1       4.103847352024925
# 2       4.196997663551385
# 3       4.479382788161983
# 4       4.238504672897215

# %%
colors = list(df_plt['County'].unique())
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
for i in range(0 , len(colors)):
    data = df_plt[df_plt['County'] == colors[i]]
    ax[0].plot(data['Year'].astype(float), data['Average Windspeed (m/s)'].astype(float), label=colors[i], alpha = 0.5)
    ax[1].plot(data['Year'].astype(float), data['Log-Yield'].astype(float), alpha = 0.5)
ax[0].set_xlabel("Year")
ax[0].set_ylabel("Average Windspeed (m/s)")
ax[0].set_title("Time Series of Wind Speed")
ax[1].set_xlabel("Year")
ax[1].set_ylabel("Log-Yield")
ax[1].set_title("Time Series of Log-Yield");

# %%
data_plt = np.array(plot_data(filenames, 'wind_100ms'))
df_plt = pd.DataFrame(data_plt, columns = ['Year', 'County', 'Log-Yield', 'GDD', 'KDD', 'Average Windspeed (m/s)'])
print(df_plt.head())
counties = list(df_plt['County'].unique())
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
for i in range(0 , len(counties)):
    data = df_plt[df_plt['County'] == counties[i]]
    ax[0].plot(data['Year'].astype(float), data['Average Windspeed (m/s)'].astype(float), label=counties[i], alpha = 0.5)
    ax[1].plot(data['Year'].astype(float), data['Log-Yield'].astype(float), alpha = 0.5)
ax[0].set_xlabel("Year")
ax[0].set_ylabel("Average Windspeed (m/s)")
ax[0].set_title("Time Series of Wind Speed")
ax[1].set_xlabel("Year")
ax[1].set_ylabel("Log-Yield")
ax[1].set_title("Time Series of Log-Yield")
fig.suptitle("With Hourly Max");
# Out:
#    Year   County           Log-Yield                GDD                  KDD  \
# 0  2007  JACKSON  4.7791234931115305    9.8280533345053   0.4832467508926889
# 1  2009  JACKSON      4.969813299576  8.183017944897191  0.23118986809024497
# 2  2010  JACKSON    4.48638664999812  9.589805020612769    0.572945128036948
# 3  2011  JACKSON    4.75617305952462   9.54341130947772    0.749284874812784
# 4  2012  JACKSON    4.00733318523247   10.5468887051604   0.9158260897377629
#
#   Average Windspeed (m/s)
# 0       7.825005841121498
# 1       7.554643691588803
# 2       7.934108255451731
# 3       8.301179906542085
# 4       8.030329049844234

# %%
data_df = pd.DataFrame(columns = ['Year', 'County', 'Log-Yield', 'GDD', 'KDD', 'Average Windspeed (m/s)', 'Windspeed Residuals', 'Log-Yield Residuals'])
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
county_names = []
for i in range(len(counties)):
    county_names.append(counties[i])
    data = df_plt[df_plt['County'] == counties[i]].copy()
    covariates = data['Year'].astype(float).values.reshape(-1, 1).copy()
    ys = data['Average Windspeed (m/s)'].astype(float).copy()
    model = LinearRegression()
    model.fit(covariates, ys)
    y_preds = model.predict(covariates)
    residuals = ys - y_preds
    data.loc[:, 'Windspeed Residuals'] = residuals # added this line!
    ax[0].plot(covariates, residuals, alpha = 0.5)
    ys2 = data['Log-Yield'].astype(float)
    model.fit(covariates, ys2)
    y_preds2 = model.predict(covariates)
    residuals2 = ys2 - y_preds2
    data.loc[:, 'Log-Yield Residuals'] = residuals2 #added this line!
    ax[1].plot(covariates, residuals2, alpha = 0.5)
    data_df = data_df.append(data)
ax[0].set_xlabel("Year")
ax[0].set_ylabel("Detrended Windspeed (m/s)")
ax[0].set_title("Residuals of Wind Speed")
ax[1].set_xlabel("Year")
ax[1].set_ylabel("Detrended Log-Yield")
ax[1].set_title("Residuals of Log-Yield");
ax[1].legend(county_names, bbox_to_anchor=(1.05, 1));

# %% [markdown]
# This appears to check out! Specifically we see a peak in wind speed residuals in 2011 which matches the negative peak in the log-yield residuals.

# %%
model = LinearRegression()
covariate = data_df['Windspeed Residuals'].astype(float).values.reshape(-1,1)
model.fit(covariate, data_df['Log-Yield Residuals'])
yield_preds = model.predict(covariate)
plt.scatter(covariate, data_df['Log-Yield Residuals'])
plt.scatter(covariate, yield_preds)
plt.xlabel("Windspeed Residuals")
plt.ylabel("Log-Yield Residuals")
print('Using just windspeed residuals')
print("\tcoefficient", model.coef_)
print("\tr-squared:", r2_score(data_df['Log-Yield Residuals'], yield_preds))
covariates_all = data_df.loc[:,['GDD', 'KDD', 'Windspeed Residuals']] #
model.fit(covariates_all, data_df['Log-Yield Residuals'])
yield_preds2 = model.predict(covariates_all)
print('Using GDD, KDD, and Windspeed Residuals')
print("\tcoefficient", model.coef_)
print("\tr-squared:", r2_score(data_df['Log-Yield Residuals'], yield_preds2))
# Out:
# Using just windspeed residuals
# 	coefficient [-0.28069295]
# 	r-squared: 0.03932290656698789
# Using GDD, KDD, and Windspeed Residuals
# 	coefficient [ 0.0911647  -1.13988035 -0.02898514]
# 	r-squared: 0.5886126763611681

# %% [markdown]
# The difference in $r^2$ between temperature and temperature with windspeed residuals only provides marginal improvement in $r^2$. We do, however, finally observe the expected coefficient for windspeed (that is, negative).
#
# # Next up is polynomial regression!

# %%
#This is done with the raw mean
test = df_plt['Average Windspeed (m/s)'].astype(float).values.reshape(-1,1)
poly = PolynomialFeatures(3, include_bias = False)
test_poly = poly.fit_transform(test)
df_plt.loc[:,'Windspeed^2'] = test_poly[:,1]
df_plt.loc[:,'Windspeed^3'] = test_poly[:,2]
covariates_all = df_plt.loc[:,['GDD', 'KDD', 'Average Windspeed (m/s)', 'Windspeed^2', 'Windspeed^3']] #
model.fit(covariates_all, data_df['Log-Yield Residuals'])
yield_preds3 = model.predict(covariates_all)
print('Using GDD, KDD, and Powers of Windspeed up to 3')
print("\tcoefficient", model.coef_)
print("\tr-squared:", r2_score(data_df['Log-Yield Residuals'], yield_preds3))
def response_func(x):
    return model.coef_[2]*x + model.coef_[3]*x**2 + model.coef_[4]*x**3
xlim = np.linspace(0, 10, 100)
plt.plot(xlim, response_func(xlim))
plt.xlabel("Average Windspeed (m/s)")
plt.ylabel("Effect on Log-Yield")
plt.title("Preliminary Wind Response Function");
# Out:
# Using GDD, KDD, and Powers of Windspeed up to 3
# 	coefficient [-0.04269762  0.10689349 -6.5154444   0.79223561 -0.03209545]
# 	r-squared: 0.0034328882611024403

# %%
#Now let's try with the detrended windspeed!
wind_resid = data_df['Windspeed Residuals'].astype(float).values.reshape(-1,1)
wind_resid_poly = poly.fit_transform(wind_resid)
data_df.loc[:,'Windspeed^2'] = wind_resid_poly[:,1]
data_df.loc[:,'Windspeed^3'] = wind_resid_poly[:,2]
covariates_all2 = data_df.loc[:,['GDD', 'KDD', 'Windspeed Residuals', 'Windspeed^2', 'Windspeed^3']]
model.fit(covariates_all2, data_df['Log-Yield Residuals'])
yield_preds4 = model.predict(covariates_all2)
print('Using GDD, KDD, and Powers of Windspeed Residuals up to 3')
print("\tcoefficient", model.coef_)
print("\tr-squared:", r2_score(data_df['Log-Yield Residuals'], yield_preds4))
def response_func2(x):
    return model.coef_[2]*x + model.coef_[3]*x**2 + model.coef_[4]*x**3
xlim = np.linspace(-2.5, 2.5, 100)
plt.plot(xlim, response_func2(xlim))
plt.xlabel("Windspeed Residuals")
plt.ylabel("Effect on Log-Yield")
plt.title("Preliminary Wind Response Function");
# Out:
# Using GDD, KDD, and Powers of Windspeed Residuals up to 3
# 	coefficient [ 0.08239143 -1.11827288 -0.02952081 -0.34265209 -0.08526303]
# 	r-squared: 0.5968389763643324

# %%
county_yield
# Out:
#        GEOID  Year     Year_2      State  State_ANSI    County  County_ANSI  \
# 0       1043  2000  4000000.0    ALABAMA         1.0   CULLMAN         43.0
# 1       1043  2001  4004001.0    ALABAMA         1.0   CULLMAN         43.0
# 2       1043  2002  4008004.0    ALABAMA         1.0   CULLMAN         43.0
# 3       1043  2003  4012009.0    ALABAMA         1.0   CULLMAN         43.0
# 4       1043  2004  4016016.0    ALABAMA         1.0   CULLMAN         43.0
# ...      ...   ...        ...        ...         ...       ...          ...
# 17755  55073  2015  4060225.0  WISCONSIN        55.0  MARATHON         73.0
# 17756  55073  2016  4064256.0  WISCONSIN        55.0  MARATHON         73.0
# 17757  55073  2017  4068289.0  WISCONSIN        55.0  MARATHON         73.0
# 17758  55073  2018  4072324.0  WISCONSIN        55.0  MARATHON         73.0
# 17759  55073  2019  4076361.0        NaN         NaN       NaN          NaN
#
#              lat        lon Commodity  ...  ln_yield      tmean  gdd_10_28  \
# 0      34.131923 -86.869267      CORN  ...  4.094345  20.728573  10.510035
# 1      34.131923 -86.869267      CORN  ...  4.990433  19.766562  10.117532
# 2      34.131923 -86.869267      CORN  ...  4.532599  20.387165  10.668972
# 3      34.131923 -86.869267      CORN  ...  4.795791  20.178537  10.298344
# 4      34.131923 -86.869267      CORN  ...  4.867534  20.461144  10.623413
# ...          ...        ...       ...  ...       ...        ...        ...
# 17755  44.898036 -89.757823      CORN  ...  4.916325  12.394336   5.418602
# 17756  44.898036 -89.757823      CORN  ...  4.998563  13.231699   5.936942
# 17757  44.898036 -89.757823      CORN  ...  5.057519  12.040596   5.076256
# 17758  44.898036 -89.757823      CORN  ...  5.013298  12.389827   6.226794
# 17759  44.898036 -89.757823       NaN  ...       NaN  11.208352   5.068023
#
#          kdd_28       ppt    swdown      smrz    smrz_2       ppt_2   swdown_2
# 0      0.662003  3.517464  5.733637       NaN       NaN   94.704399  35.756950
# 1      0.287366  4.715416  5.418226       NaN       NaN  116.203275  32.780945
# 2      0.420518  4.802636  5.537177       NaN       NaN  122.546751  33.485168
# 3      0.272478  4.536163  5.230230       NaN       NaN  116.863832  30.876053
# 4      0.309911  3.485957  5.515142       NaN       NaN   64.746069  32.963717
# ...         ...       ...       ...       ...       ...         ...        ...
# 17755  0.015156  2.807155  5.303140  0.285819  0.083682   49.407322  31.395783
# 17756  0.033743  3.478422  5.224859  0.293680  0.087793   63.899416  30.904053
# 17757  0.010749  3.679466  5.019314  0.315527  0.102483   58.761838  29.225135
# 17758  0.078514  2.780134  5.309081  0.233532  0.059132   58.192321  31.591917
# 17759  0.015933  3.652517  5.102417       NaN       NaN   73.694211  29.852238
#
# [17760 rows x 22 columns]

# %%
county_2019 = county_yield[(county_yield['Year']==2019) & (county_yield['State'] == 'KANSAS')].copy()
county_2019['FIPS'] = [int(f"{int(county_2019['State_ANSI'].values[i])}{int(county_2019['County_ANSI'].values[i]):03}") for i in range(0,len(county_2019))]
county_2019
# Out:
#       GEOID  Year     Year_2   State  State_ANSI        County  County_ANSI  \
# 4999  20115  2019  4076361.0  KANSAS        20.0        MARION        115.0
# 5019  20113  2019  4076361.0  KANSAS        20.0     MCPHERSON        113.0
# 5039  20003  2019  4076361.0  KANSAS        20.0      ANDERSON          3.0
# 5059  20031  2019  4076361.0  KANSAS        20.0        COFFEY         31.0
# 5079  20045  2019  4076361.0  KANSAS        20.0       DOUGLAS         45.0
# 5099  20111  2019  4076361.0  KANSAS        20.0          LYON        111.0
# 5119  20121  2019  4076361.0  KANSAS        20.0         MIAMI        121.0
# 5139  20127  2019  4076361.0  KANSAS        20.0        MORRIS        127.0
# 5159  20139  2019  4076361.0  KANSAS        20.0         OSAGE        139.0
# 5179  20177  2019  4076361.0  KANSAS        20.0       SHAWNEE        177.0
# 5199  20013  2019  4076361.0  KANSAS        20.0         BROWN         13.0
# 5219  20085  2019  4076361.0  KANSAS        20.0       JACKSON         85.0
# 5239  20117  2019  4076361.0  KANSAS        20.0      MARSHALL        117.0
# 5259  20149  2019  4076361.0  KANSAS        20.0  POTTAWATOMIE        149.0
# 5279  20079  2019  4076361.0  KANSAS        20.0        HARVEY         79.0
# 5299  20191  2019  4076361.0  KANSAS        20.0        SUMNER        191.0
# 5319  20021  2019  4076361.0  KANSAS        20.0      CHEROKEE         21.0
# 5339  20125  2019  4076361.0  KANSAS        20.0    MONTGOMERY        125.0
# 5359  20205  2019  4076361.0  KANSAS        20.0        WILSON        205.0
#
#             lat        lon Commodity  ...      tmean  gdd_10_28    kdd_28  \
# 4999  38.359647 -97.102771      CORN  ...  18.129561   9.113462  0.465753
# 5019  38.395812 -97.647489      CORN  ...  17.979423   8.973756  0.520753
# 5039  38.215114 -95.292046      CORN  ...  18.101124   9.087264  0.324209
# 5059  38.236450 -95.729137      CORN  ...  18.086648   9.111700  0.317176
# 5079  38.896415 -95.290946      CORN  ...  17.666728   8.848923  0.278067
# 5099  38.455498 -96.161589      CORN  ...  17.882676   8.990702  0.333738
# 5119  38.566772 -94.832963      CORN  ...  17.851329   8.938551  0.259382
# 5139  38.688204 -96.651448      CORN  ...  17.625975   8.820070  0.358376
# 5159  38.648409 -95.707596      CORN  ...  17.903794   8.995353  0.328748
# 5179  39.041805 -95.755664      CORN  ...  17.740027   8.912866  0.320283
# 5199  39.825931 -95.569905      CORN  ...  16.844737   8.352533  0.254702
# 5219  39.411145 -95.794485      CORN  ...  17.043042   8.465397  0.270148
# 5239  39.782709 -96.521243      CORN  ...  16.610903   8.238958  0.265093
# 5259  39.382187 -96.337113      CORN  ...  16.936669   8.395338  0.275995
# 5279  38.050144 -97.436706      CORN  ...  18.439581   9.268405  0.544681
# 5299  37.236662 -97.493352      CORN  ...  19.026927   9.589145  0.589423
# 5319  37.169392 -94.845697      CORN  ...  18.804860   9.607597  0.316421
# 5339  37.189537 -95.742403      CORN  ...  18.937734   9.698392  0.380318
# 5359  37.558515 -95.745175      CORN  ...  18.711180   9.509099  0.371757
#
#            ppt    swdown  smrz  smrz_2       ppt_2   swdown_2   FIPS
# 4999  5.317713  5.730516   NaN     NaN  210.735370  36.502879  20115
# 5019  4.478953  5.767339   NaN     NaN  142.012134  36.969369  20113
# 5039  6.808824  5.520412   NaN     NaN  307.611414  34.379861  20003
# 5059  6.204870  5.520412   NaN     NaN  241.602339  34.379861  20031
# 5079  6.364225  5.518816   NaN     NaN  303.337573  34.297091  20045
# 5099  5.427817  5.633127   NaN     NaN  169.088992  35.507031  20111
# 5119  6.151249  5.439328   NaN     NaN  211.799662  33.585819  20121
# 5139  4.727703  5.648565   NaN     NaN  145.294228  35.706379  20127
# 5159  5.963378  5.520412   NaN     NaN  205.536977  34.379861  20139
# 5179  5.509413  5.514338   NaN     NaN  167.581414  34.151873  20177
# 5199  5.453917  5.506727   NaN     NaN  153.872298  34.220581  20013
# 5219  5.525535  5.513205   NaN     NaN  143.433057  34.266129  20085
# 5239  4.872463  5.597326   NaN     NaN  112.952495  35.147118  20117
# 5259  5.397128  5.597326   NaN     NaN  150.357881  35.147118  20149
# 5279  5.111851  5.764304   NaN     NaN  192.274113  36.831446  20079
# 5299  5.384456  5.758565   NaN     NaN  246.455038  37.036172  20191
# 5319  6.585303  5.424598   NaN     NaN  248.887641  33.797243  20021
# 5339  5.920810  5.511262   NaN     NaN  241.036295  34.638139  20125
# 5359  6.080150  5.511262   NaN     NaN  285.963428  34.638139  20205
#
# [19 rows x 23 columns]

# %%
fig = ff.create_choropleth(fips=county_2019['FIPS'], values=county_2019['ln_yield'].values, 
                           legend_title = 'Log Yield',
                           show_hover=True, asp=2.9,
                           title_text = 'Log Yield for Selected Kansas Counties 2019',
                           scope=['KA', 'NE','MO','OK'],
                          round_legend_values = True)
fig.layout.template = None

fig.show()
# Out:
# <div>                            <div id="ce9d447d-1c92-4689-9d69-a202b6b5817b" class="plotly-graph-div" style="height:450px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce9d447d-1c92-4689-9d69-a202b6b5817b")) {                    Plotly.newPlot(                        "ce9d447d-1c92-4689-9d69-a202b6b5817b",                        [{"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "4.53259949315326", "type": "scatter", "x": [-97.80760000000001, -97.153331, -97.14772099999999, -97.8023129924768, -97.80760000000001, null], "y": [37.474184, 37.475544, 36.999111, 36.998712977542695, 37.474184, null]}, {"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "4.56538931597625", "type": "scatter", "x": [-96.357028, -96.35261299999999, -95.94592399999999, -95.958862, -96.357028, null], "y": [38.175425, 38.739021, 38.739112, 38.170939, 38.175425, null]}, {"fill": "toself", "fillcolor": "rgb(72, 24, 106)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "4.60616968632118", "type": "scatter", "x": [-97.371932, -97.371911, -97.150746, -96.930286, -96.929969, -96.819723, -96.840772, -97.152913, -97.153093, -97.37174999999999, -97.371932, null], "y": [38.522161, 38.609353, 38.609559999999995, 38.609362, 38.522411999999996, 38.522464, 38.085622, 38.087703999999995, 38.174634, 38.173673, 38.522161, null]}, {"fill": "toself", "fillcolor": "rgb(71, 45, 123)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "4.61512051684126", "type": "scatter", "x": [-96.933022, -96.927234, -96.890171, -96.890245, -96.501556, -96.501397, -96.39039799999999, -96.389749, -96.35261, -96.35378, -96.929969, -96.933022, null], "y": [38.657858, 38.81216, 38.812169, 38.870067, 38.869704, 38.826187999999995, 38.825858, 38.738983999999995, 38.739261, 38.521657, 38.522411999999996, 38.657858, null]}, {"fill": "toself", "fillcolor": "rgb(66, 64, 134)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "4.69318106331081", "type": "scatter", "x": [-97.702164, -97.701841, -97.153093, -97.152476, -97.70196899999999, -97.702164, null], "y": [38.073582, 38.173814, 38.174634, 37.912732999999996, 37.911325, 38.073582, null]}, {"fill": "toself", "fillcolor": "rgb(59, 82, 139)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "4.713127327493179", "type": "scatter", "x": [-95.518728, -95.50832799999999, -95.06583099999999, -95.07787599999999, -95.51897, -95.518728, null], "y": [38.103718, 38.390277999999995, 38.389945, 38.037706, 38.03823, 38.103718, null]}, {"fill": "toself", "fillcolor": "rgb(51, 99, 141)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "4.724729421045731", "type": "scatter", "x": [-95.96457099999999, -95.964666, -95.52113, -95.5224149880945, -95.9642699335572, -95.96457099999999, null], "y": [37.067578999999995, 37.386655999999995, 37.38399, 36.9992810582678, 36.9990936072442, 37.067578999999995, null]}, {"fill": "toself", "fillcolor": "rgb(44, 114, 142)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "4.74493212836325", "type": "scatter", "x": [-95.958916, -95.950282, -95.50826699999999, -95.51897, -95.959046, -95.958916, null], "y": [38.112781999999996, 38.434104999999995, 38.433932999999996, 38.03823, 38.040195, 38.112781999999996, null]}, {"fill": "toself", "fillcolor": "rgb(38, 130, 142)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "4.750135956238281", "type": "scatter", "x ...

# %%
county_large = pd.read_csv("../../data/data_yield/Maize_1999_2019_NASS.csv")

# %%
county_2019 = county_yield.dropna()[(county_yield['Year']==2018)].copy()
county_2019['FIPS'] = [int(f"{int(county_2019['State_ANSI'].values[i])}{int(county_2019['County_ANSI'].values[i]):03}") for i in range(0,len(county_2019))]
fig = ff.create_choropleth(fips=county_2019['FIPS'], values=county_2019['ln_yield'].values, 
                           legend_title = 'Log Yield',
                           show_hover=True, asp=2.9,
                           title_text = 'Log Yield for Selected Kansas Counties 2019',
                          round_legend_values = True)
fig.layout.template = None

fig.show()
# Out:
# /Users/julianschmitt/opt/anaconda3/envs/covid/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# <div>                            <div id="fcf0d04d-a69d-4cd4-baf0-33c2d06b3c82" class="plotly-graph-div" style="height:450px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcf0d04d-a69d-4cd4-baf0-33c2d06b3c82")) {                    Plotly.newPlot(                        "fcf0d04d-a69d-4cd4-baf0-33c2d06b3c82",                        [{"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "3.9259259105971402", "type": "scatter", "x": [-96.933022, -96.927234, -96.890171, -96.890245, -96.501556, -96.501397, -96.39039799999999, -96.389749, -96.35261, -96.35378, -96.929969, -96.933022, null], "y": [38.657858, 38.81216, 38.812169, 38.870067, 38.869704, 38.826187999999995, 38.825858, 38.738983999999995, 38.739261, 38.521657, 38.522411999999996, 38.657858, null]}, {"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "4.03246915850401", "type": "scatter", "x": [-97.91384699999999, -97.418606, -97.343426, -97.27811299999999, -97.070188, -97.25908199999999, -97.315507, -97.625051, -97.82851199999999, -97.91384699999999, null], "y": [31.065882, 31.320202, 31.244214999999997, 31.279798999999997, 30.98622, 30.889595999999997, 30.752371, 30.870372, 30.906188, 31.065882, null]}, {"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "4.0552571735140495", "type": "scatter", "x": [-98.31092799999999, -98.089941, -97.875259, -97.763364, -97.63101999999999, -97.84038299999999, -98.113175, -98.122322, -98.185085, -98.222653, -98.267432, -98.31092799999999, null], "y": [29.594472999999997, 29.683479, 29.858207999999998, 29.713041999999998, 29.653471999999997, 29.376790999999997, 29.365667, 29.477646, 29.486089, 29.549032, 29.544178, 29.594472999999997, null]}, {"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "4.096009841541161", "type": "scatter", "x": [-98.159266, -98.049886, -98.006276, -97.917063, -97.926985, -97.86786599999999, -97.84831, -97.775785, -97.576545, -97.36953899999999, -97.492482, -97.71021499999999, -98.17297699999999, -98.159266, null], "y": [30.376651, 30.624155, 30.627516, 30.604871, 30.567653999999997, 30.546498999999997, 30.47261, 30.429800999999998, 30.501825, 30.419563, 30.210010999999998, 30.024499, 30.356312, 30.376651, null]}, {"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "4.12390336446365", "type": "scatter", "x": [-97.31484599999999, -97.25908199999999, -96.82962099999999, -96.82033299999999, -96.766302, -96.772348, -96.747091, -96.772362, -96.75632999999999, -96.68496999999999, -96.694853, -96.61196699999999, -97.155219, -97.271418, -97.31484599999999, null], "y": [30.754416, 30.889595999999997, 31.110545, 31.060955, 31.048251999999998, 31.006729, 31.000950999999997, 30.969064999999997, 30.927205999999998, 30.906191, 30.864517, 30.757645, 30.457344, 30.735692, 30.754416, null]}, {"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "4.12713438504509", "type": "scatter", "x": [-97.497086, -97.456462, -97.475985, -97.086191, -96.94065599999999, -96.896209, -96.71911399999999, -96.932215, -97.037266, -97.277265, -97.32652999999999, -97.279529, -97.382848, -97.35936699999999, -97.439471, -97.377758, -97.42638699999999, -97.485968, -97.469933, -97.497086, null], "y": [32.134344999999996, 32.164358, 32.181678999999995, 32.265451, 32.052087, 32.073977, 31.814887, 31.708886999999997, 31.863079, 31. ...

# %%
print("hello")
