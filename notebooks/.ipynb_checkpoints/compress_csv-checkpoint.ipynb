# %% [markdown]
# # Compress Data for Transfer

# %% [markdown]
# Goal of this script is to resample the downloaded csvs by taking the max hourly windspeed and then averaging across the 3 stations per county. This should result in ~50x factor of compression and will be more manageable

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from tqdm import tqdm

# %%
# get filepathing
state = "Ohio"
path = "/Users/julianschmitt/Downloads/Direcho/{}".format(state)
files = os.listdir(path)
paths = [os.path.join(path, f) for f in files]
try:
    os.mkdir("/Users/julianschmitt/Downloads/Direcho/processed/{}".format(state))
except:
    print("Directory already made.")

# %%
# Print total number of unique counties
counties = np.unique(["_".join(file.split("_")[1:3]) for file in files])

def process_raw(path):
    """ Take max of wind speed parameters and mean of temperature """
    wind = pd.read_csv(path, low_memory=False)
    process = wind.groupby(["Year","Month","Day","Hour"])[["wind speed at 10m (m/s)", \
                                                                 'wind speed at 40m (m/s)', \
                                                                 "wind speed at 100m (m/s)"]].max()
    process['air temperature at 10m (C)'] = wind.groupby(["Year","Month","Day",\
                                                           "Hour"])[['air temperature at 10m (C)']].mean()
    return process

# %%
#ar = [i for i in files if counties[0] in i]
for ind in tqdm(range(len(paths))): #len(paths)
    try:
        processed = process_raw(paths[ind])
        #print(processed.head())
        year, month, day, hour = [elt[0] for elt in processed.index],[elt[1] for elt in processed.index], \
                            [elt[2] for elt in processed.index], [elt[3] for elt in processed.index]
        wind_10, wind_40, wind_100, temp_10 = [elt[0] for elt in processed.values], [elt[1] for elt in processed.values],\
                        [elt[2] for elt in processed.values], [elt[3] for elt in processed.values]
        cleaned = pd.DataFrame({"Year":year, "Month":month, "Day":day, "Hour": hour, 'wind_10ms':wind_10, \
                  'wind_40ms':wind_40, 'wind_100ms':wind_100,'temp_10':temp_10})
        new_loc = "/Users/julianschmitt/Downloads/Direcho/processed/{}/{}".format(state,files[ind])
#         if os.path.isdir(new_loc) == False:
#             os.mkdir(os.path.dirname(new_loc))
        cleaned.to_csv(new_loc)
    except:
        print("{} could not be loaded".format(files[ind]))
# Out:
# 100%|██████████| 179/179 [13:26<00:00,  4.51s/it]

# %%
lst = [elt for elt in paths if counties[0] in elt]
lst
# Out:
# ['/Users/julianschmitt/Downloads/Direcho/Nebraska/50861_Nebraska_Adams_5.csv',
#  '/Users/julianschmitt/Downloads/Direcho/Nebraska/51019_Nebraska_Adams_5.csv',
#  '/Users/julianschmitt/Downloads/Direcho/Nebraska/50862_Nebraska_Adams_5.csv']

# %%
os.path.dirname(paths[0])
# Out:
# '/Users/julianschmitt/Downloads/Direcho/Nebraska'

# %%
files2=os.listdir("../../direcho_compact")
dif = set(files).difference(set(files2))
dif
# Out:
# {'.DS_Store'}

# %%
wind = pd.read_csv(f"../../direcho_data/{ar[0]}")
processed = wind.groupby(["Year","Month","Day","Hour"])[["wind speed at 10m (m/s)",'wind speed at 40m (m/s)',"wind speed at 100m (m/s)",'air temperature at 100m (C)']].max()

# %%
print(processed)
# Out:
#                      wind speed at 10m (m/s)  wind speed at 40m (m/s)  \
# Year Month Day Hour
# 2007 1     1   0                        7.26                     9.81
#                1                        6.96                     9.44
#                2                        7.08                     9.58
#                3                        6.84                     9.37
#                4                        6.63                     9.12
# ...                                      ...                      ...
# 2014 12    31  19                       6.24                     7.25
#                20                       6.34                     7.44
#                21                       6.12                     7.44
#                22                       5.48                     7.18
#                23                       3.73                     6.64
#
#                      wind speed at 100m (m/s)  air temperature at 100m (C)
# Year Month Day Hour
# 2007 1     1   0                        11.85                        -1.85
#                1                        11.55                        -2.19
#                2                        11.70                        -2.59
#                3                        11.57                        -2.55
#                4                        11.44                        -2.49
# ...                                       ...                          ...
# 2014 12    31  19                        7.84                        -3.51
#                20                        8.09                        -3.07
#                21                        8.35                        -2.89
#                22                        8.62                        -2.92
#                23                        8.28                        -2.82
#
# [70080 rows x 4 columns]

# %%
print(type(processed))
year, month, day, hour = [elt[0] for elt in processed.index],[elt[1] for elt in processed.index], \
                        [elt[2] for elt in processed.index], [elt[3] for elt in processed.index]
wind_10, wind_40, wind_100, temp_100 = [elt[0] for elt in processed.values], [elt[1] for elt in processed.values],\
                    [elt[2] for elt in processed.values], [elt[3] for elt in processed.values]
pd.DataFrame({"Year":year, "Month":month, "Day":day, "Hour": hour, 'wind_10ms':wind_10, \
              'wind_40ms':wind_40, 'wind_100ms':wind_100,'temp_100':temp_100})
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        Year  Month  Day  Hour  wind_10ms  wind_40ms  wind_100ms  temp_100
# 0      2007      1    1     0       7.26       9.81       11.85     -1.85
# 1      2007      1    1     1       6.96       9.44       11.55     -2.19
# 2      2007      1    1     2       7.08       9.58       11.70     -2.59
# 3      2007      1    1     3       6.84       9.37       11.57     -2.55
# 4      2007      1    1     4       6.63       9.12       11.44     -2.49
# ...     ...    ...  ...   ...        ...        ...         ...       ...
# 70075  2014     12   31    19       6.24       7.25        7.84     -3.51
# 70076  2014     12   31    20       6.34       7.44        8.09     -3.07
# 70077  2014     12   31    21       6.12       7.44        8.35     -2.89
# 70078  2014     12   31    22       5.48       7.18        8.62     -2.92
# 70079  2014     12   31    23       3.73       6.64        8.28     -2.82
#
# [70080 rows x 8 columns]

# %%
wind.iloc[0:24][['Hour','wind speed at 10m (m/s)']]
# Out:
#     Hour  wind speed at 10m (m/s)
# 0      0                     6.28
# 1      0                     6.50
# 2      0                     6.92
# 3      0                     7.13
# 4      0                     7.13
# 5      0                     7.18
# 6      0                     7.26
# 7      0                     6.87
# 8      0                     6.96
# 9      0                     6.71
# 10     0                     6.71
# 11     0                     6.89
# 12     1                     6.96
# 13     1                     6.93
# 14     1                     6.94
# 15     1                     6.92
# 16     1                     6.74
# 17     1                     6.74
# 18     1                     6.76
# 19     1                     6.79
# 20     1                     6.85
# 21     1                     6.90
# 22     1                     6.92
# 23     1                     6.96

# %%
files
# Out:
# ['43780_Kansas_Jackson_5.csv',
#  '41464_Kansas_Russell_5.csv',
#  '36362_Kansas_Haskell_5.csv',
#  '46878_Kansas_Republic_5.csv',
#  '31911_Kansas_Chautauqua_5.csv',
#  '39397_Kansas_Finney_5.csv',
#  '41353_Kansas_Ellsworth_5.csv',
#  '38830_Kansas_Pawnee_5.csv',
#  '43161_Kansas_Riley_5.csv',
#  '32521_Kansas_Morton_5.csv',
#  '35967_Kansas_Kingman_5.csv',
#  '39245_Kansas_Lyon_5.csv',
#  '41456_Kansas_Ness_5.csv',
#  '34930_Kansas_Ford_5.csv',
#  '38327_Kansas_Greenwood_5.csv',
#  '43977_Kansas_Rooks_5.csv',
#  '31780_Kansas_Montgomery_5.csv',
#  '45566_Kansas_Marshall_5.csv',
#  '37995_Kansas_Hodgeman_5.csv',
#  '45915_Kansas_Smith_5.csv',
#  '44184_Kansas_Rooks_5.csv',
#  '39904_Kansas_Franklin_5.csv',
#  '33028_Kansas_Barber_5.csv',
#  '31771_Kansas_Morton_5.csv',
#  '32143_Kansas_Stevens_5.csv',
#  '47967_Kansas_Cheyenne_5.csv',
#  '46987_Kansas_Republic_5.csv',
#  '43873_Kansas_Sheridan_5.csv',
#  '33291_Kansas_Barber_5.csv',
#  '46339_Kansas_Rawlins_5.csv',
#  '36612_Kansas_Grant_5.csv',
#  '33299_Kansas_Kingman_5.csv',
#  '47269_Kansas_Doniphan_5.csv',
#  '40614_Kansas_Wichita_5.csv',
#  '.DS_Store',
#  '39133_Kansas_McPherson_5.csv',
#  '34612_Kansas_Neosho_5.csv',
#  '31907_Kansas_Stevens_5.csv',
#  '47563_Kansas_Brown_5.csv',
#  '33173_Kansas_Wilson_5.csv',
#  '35968_Kansas_Sedgwick_5.csv',
#  '40611_Kansas_Wichita_5.csv',
#  '30996_Kansas_Montgomery_5.csv',
#  '32279_Kansas_Labette_5.csv',
#  '38113_Kansas_Stafford_5.csv',
#  '32543_Kansas_Cherokee_5.csv',
#  '39134_Kansas_McPherson_5.csv',
#  '41682_Kansas_Wabaunsee_5.csv',
#  '34568_Kansas_Meade_5.csv',
#  '40266_Kansas_Greeley_5.csv',
#  '42450_Kansas_Lincoln_5.csv',
#  '47686_Kansas_Jewell_5.csv',
#  '44458_Kansas_Cloud_5.csv',
#  '45564_Kansas_Marshall_5.csv',
#  '44877_Kansas_Pottawatomie_5.csv',
#  '44514_Kansas_Sherman_5.csv',
#  '41566_Kansas_Ness_5.csv',
#  '43335_Kansas_Gove_5.csv',
#  '36485_Kansas_Grant_5.csv',
#  '40709_Kansas_Barton_5.csv',
#  '39331_Kansas_Anderson_5.csv',
#  '47828_Kansas_Phillips_5.csv',
#  '33606_Kansas_Neosho_5.csv',
#  '47543_Kansas_Jewell_5.csv',
#  '37991_Kansas_Hodgeman_5.csv',
#  '43258_Kansas_Wyandotte_5.csv',
#  '33156_Kansas_Barber_5.csv',
#  '41785_Kansas_Wabaunsee_5.csv',
#  '41336_Kansas_Ness_5.csv',
#  '37559_Kansas_Allen_5.csv',
#  '44965_Kansas_Pottawatomie_5.csv',
#  '40048_Kansas_Rush_5.csv',
#  '45449_Kansas_Mitchell_5.csv',
#  '35800_Kansas_Kiowa_5.csv',
#  '44190_Kansas_Clay_5.csv',
#  '44882_Kansas_Atchison_5.csv',
#  '46645_Kansas_Republic_5.csv',
#  '42887_Kansas_Johnson_5.csv',
#  '38943_Kansas_Marion_5.csv',
#  '38101_Kansas_Edwards_5.csv',
#  '34757_Kansas_Ford_5.csv',
#  '41465_Kansas_Russell_5.csv',
#  '42443_Kansas_Lincoln_5.csv',
#  '43781_Kansas_Jackson_5.csv',
#  '44794_Kansas_Atchison_5.csv',
#  '39132_Kansas_McPherson_5.csv',
#  '30831_Kansas_Comanche_5.csv',
#  '34217_Kansas_Kiowa_5.csv',
#  '43696_Kansas_Riley_5.csv',
#  '32028_Kansas_Stevens_5.csv',
#  '41077_Kansas_Dickinson_5.csv',
#  '36385_Kansas_Pratt_5.csv',
#  '41485_Kansas_Osage_5.csv',
#  '43533_Kansas_Wyandotte_5.csv',
#  '34033_Kansas_Meade_5.csv',
#  '41889_Kansas_Ellsworth_5.csv',
#  '42651_Kansas_Wallace_5.csv',
#  '41155_Kansas_Saline_5.csv',
#  '39744_Kansas_Coffey_5.csv',
#  '38944_Kansas_Marion_5.csv',
#  '45666_Kansas_Marshall_5.csv',
#  '44356_Kansas_Graham_5.csv',
#  '39222_Kansas_Rice_5.csv',
#  '42011_Kansas_Johnson_5.csv',
#  '41896_Kansas_Wabaunsee_5.csv',
#  '38204_Kansas_Edwards_5.csv',
#  '44460_Kansas_Cloud_5.csv',
#  '38326_Kansas_Greenwood_5.csv',
#  '38945_Kansas_Marion_5.csv',
#  '42268_Kansas_Logan_5.csv',
#  '32673_Kansas_Cherokee_5.csv',
#  '33439_Kansas_Kingman_5.csv',
#  '33448_Kansas_Sumner_5.csv',
#  '47973_Kansas_Smith_5.csv',
#  '41157_Kansas_Saline_5.csv',
#  '30833_Kansas_Comanche_5.csv',
#  '44796_Kansas_Atchison_5.csv',
#  '47544_Kansas_Jewell_5.csv',
#  '35496_Kansas_Pratt_5.csv',
#  '46338_Kansas_Rawlins_5.csv',
#  '41156_Kansas_Saline_5.csv',
#  '41073_Kansas_Dickinson_5.csv',
#  '42653_Kansas_Ellis_5.csv',
#  '33600_Kansas_Wilson_5.csv',
#  '36787_Kansas_Reno_5.csv',
#  '40867_Kansas_Scott_5.csv',
#  '38737_Kansas_Anderson_5.csv',
#  '37243_Kansas_Kearny_5.csv',
#  '47827_Kansas_Cheyenne_5.csv',
#  '41584_Kansas_Morris_5.csv',
#  '46171_Kansas_Rawlins_5.csv',
#  '32277_Kansas_Cowley_5.csv',
#  '38724_Kansas_Pawnee_5.csv',
#  '43778_Kansas_Sheridan_5.csv',
#  '32786_Kansas_Seward_5.csv',
#  '43339_Kansas_Trego_5.csv',
#  '33889_Kansas_Elk_5.csv',
#  '44350_Kansas_Thomas_5.csv',
#  '34558_Kansas_Stanton_5.csv',
#  '32276_Kansas_Cowley_5.csv',
#  '45039_Kansas_Osborne_5.csv',
#  '38423_Kansas_Greenwood_5.csv',
#  '37788_Kansas_Woodson_5.csv',
#  '37965_Kansas_Hamilton_5.csv',
#  '33567_Kansas_Seward_5.csv',
#  '42652_Kansas_Ellis_5.csv',
#  '38296_Kansas_Gray_5.csv',
#  '31295_Kansas_Montgomery_5.csv',
#  '32151_Kansas_Labette_5.csv',
#  '43525_Kansas_Trego_5.csv',
#  '39247_Kansas_Anderson_5.csv',
#  '42813_Kansas_Geary_5.csv',
#  '36213_Kansas_Grant_5.csv',
#  '44513_Kansas_Sherman_5.csv',
#  '44955_Kansas_Osborne_5.csv',
#  '38837_Kansas_Harvey_5.csv',
#  '33569_Kansas_Clark_5.csv',
#  '34392_Kansas_Clark_5.csv',
#  '36233_Kansas_Ford_5.csv',
#  '39736_Kansas_Rice_5.csv',
#  '40705_Kansas_Wichita_5.csv',
#  '36652_Kansas_Sedgwick_5.csv',
#  '34561_Kansas_Meade_5.csv',
#  '43523_Kansas_Gove_5.csv',
#  '38119_Kansas_Butler_5.csv',
#  '44696_Kansas_Leavenworth_5.csv',
#  '38951_Kansas_Linn_5.csv',
#  '47993_Kansas_Brown_5.csv',
#  '33312_Kansas_Crawford_5.csv',
#  '37626_Kansas_Finney_5.csv',
#  '38118_Kansas_Butler_5.csv',
#  '39560_Kansas_Chase_5.csv',
#  '37751_Kansas_Finney_5.csv',
#  '44272_Kansas_Thomas_5.csv',
#  '43256_Kansas_Jefferson_5.csv',
#  '43782_Kansas_Jackson_5.csv',
#  '47849_Kansas_Nemaha_5.csv',
#  '39145_Kansas_Chase_5.csv',
#  '39151_Kansas_Linn_5.csv',
#  '41466_Kansas_Russell_5.csv',
#  '45450_Kansas_Mitchell_5.csv',
#  '33907_Kansas_Neosho_5.csv',
#  '32909_Kansas_Harper_5.csv',
#  '36389_Kansas_Sedgwick_5.csv',
#  '38723_Kansas_Pawnee_5.csv',
#  '38409_Kansas_Edwards_5.csv',
#  '36384_Kansas_Pratt_5.csv',
#  '47252_Kansas_Norton_5.csv',
#  '37560_Kansas_Bourbon_5.csv',
#  '33285_Kansas_Clark_5.csv',
#  '46438_Kansas_Brown_5.csv',
#  '41488_Kansas_Douglas_5.csv',
#  '40278_Kansas_Rice_5.csv',
#  '36617_Kansas_Haskell_5.csv',
#  '38192_Kansas_Gray_5.csv',
#  '44270_Kansas_Thomas_5.csv',
#  '46176_Kansas_Doniphan_5.csv',
#  '45751_Kansas_Washington_5.csv',
#  '43978_Kansas_Rooks_5.csv',
#  '46174_Kansas_Smith_5.csv',
#  '38117_Kansas_Butler_5.csv',
#  '32150_Kansas_Labette_5.csv',
#  '33597_Kansas_Elk_5.csv',
#  '44517_Kansas_Sherman_5.csv',
#  '34966_Kansas_Crawford_5.csv',
#  '44876_Kansas_Pottawatomie_5.csv',
#  '39128_Kansas_Stafford_5.csv',
#  '40121_Kansas_Rush_5.csv',
#  '38941_Kansas_Reno_5.csv',
#  '41779_Kansas_Morris_5.csv',
#  '42364_Kansas_Lincoln_5.csv',
#  '43438_Kansas_Trego_5.csv',
#  '44697_Kansas_Leavenworth_5.csv',
#  '41364_Kansas_Franklin_5.csv',
#  '39152_Kansas_Linn_5.csv',
#  '44954_Kansas_Osborne_5.csv',
#  '44095_Kansas_Ottawa_5.csv',
#  '41869_Kansas_Scott_5.csv',
#  '41363_Kansas_Osage_5.csv',
#  '44459_Kansas_Cloud_5.csv',
#  '47991_Kansas_Nemaha_5.csv',
#  '42010_Kansas_Douglas_5.csv',
#  '47988_Kansas_Nemaha_5.csv',
#  '45555_Kansas_Washington_5.csv',
#  '47829_Kansas_Phillips_5.csv',
#  '41995_Kansas_Ellsworth_5.csv',
#  '45448_Kansas_Mitchell_5.csv',
#  '47270_Kansas_Doniphan_5.csv',
#  '31900_Kansas_Morton_5.csv',
#  '47968_Kansas_Phillips_5.csv',
#  '39821_Kansas_Chase_5.csv',
#  '33036_Kansas_Harper_5.csv',
#  '42192_Kansas_Shawnee_5.csv',
#  '42885_Kansas_Shawnee_5.csv',
#  '38071_Kansas_Hamilton_5.csv',
#  '36497_Kansas_Haskell_5.csv',
#  '43779_Kansas_Graham_5.csv',
#  '41161_Kansas_Dickinson_5.csv',
#  '45830_Kansas_Washington_5.csv',
#  '32672_Kansas_Cherokee_5.csv',
#  '34412_Kansas_Kiowa_5.csv',
#  '30832_Kansas_Comanche_5.csv',
#  '42654_Kansas_Ellis_5.csv',
#  '34061_Kansas_Wilson_5.csv',
#  '39150_Kansas_Lyon_5.csv',
#  '43776_Kansas_Sheridan_5.csv',
#  '38940_Kansas_Reno_5.csv',
#  '32278_Kansas_Cowley_5.csv',
#  '40786_Kansas_Scott_5.csv',
#  '38390_Kansas_Gray_5.csv',
#  '33598_Kansas_Elk_5.csv',
#  '41489_Kansas_Douglas_5.csv',
#  '47685_Kansas_Decatur_5.csv',
#  '39969_Kansas_Rush_5.csv',
#  '37787_Kansas_Hodgeman_5.csv',
#  '32148_Kansas_Harper_5.csv',
#  '32923_Kansas_Crawford_5.csv',
#  '40188_Kansas_Lane_5.csv',
#  '40788_Kansas_Barton_5.csv',
#  '40066_Kansas_Osage_5.csv',
#  '39149_Kansas_Lyon_5.csv',
#  '40450_Kansas_Morris_5.csv',
#  '42984_Kansas_Shawnee_5.csv',
#  '40789_Kansas_Barton_5.csv',
#  '43338_Kansas_Gove_5.csv',
#  '44609_Kansas_Leavenworth_5.csv',
#  '38206_Kansas_Stafford_5.csv',
#  '39984_Kansas_Miami_5.csv']
